# %%
import numpy as np
import os

# FOLDER = "noise_baseline_20251209_DM"
FOLDER = "hr-2_20251209_DM-1_NS-2"

FILE = os.path.join("data", FOLDER, "tempF_dur-1.00min_fs-200Hz_idx-000_label-T.npz")

# %%
# load npz
data = np.load(FILE, allow_pickle=True)

# %%
print(data.files)
# Out:
# ['time', 'data_F', 'labels']

# %%
print(data['time'].shape)
print(data['data_F'].shape)
print(data['labels'].shape)
# Out:
# (1, 12001)
# (1, 12001)
# (1, 12001)

# %%
print(data['time'][:10])
print(data['data_F'][:10])
print(data['labels'][:10])
# Out:
# [[0.0000e+00 5.0000e-03 1.0000e-02 ... 5.9990e+01 5.9995e+01 6.0000e+01]]
# [[99.41 99.41 99.41 ... 99.34 99.34 99.34]]
# [[70.03 70.03 70.03 ... 82.53 82.53 82.53]]

# %%
# plot hr over time
import matplotlib.pyplot as plt
# plt.plot(data['time'].flatten(), data['labels'].flatten())
plt.plot(np.arange(data['labels'].shape[1]), data['labels'].flatten())
plt.show()

# %%
plt.plot(np.arange(data['labels'].shape[1]), data['data_F'].flatten())
plt.show()

# %%
# plot data_F vs heart rate
plt.scatter(data['data_F'].flatten(), data['labels'].flatten())
plt.show()
